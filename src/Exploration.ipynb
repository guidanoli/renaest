# %% [markdown]
# # Exploration
#
# This notebook is intended to explore the data before processing it.
# We have the following CSVs:

# %%
from pathlib import Path

# Directory with all CSVs
DATA_PATH = Path('..') / "data"

# Store the path of each individual CSV
ACCIDENTS_PATH = DATA_PATH / "Acidentes_DadosAbertos_20220912.csv"
# LOCALITIES_PATH = DATA_PATH / "Localidade_DadosAbertos_20220912.csv"
VEHICLES_PATH = DATA_PATH / "TipoVeiculo_DadosAbertos_20220912.csv"
VICTIMS_PATH = DATA_PATH / "Vitimas_DadosAbertos_20220912.csv"

# %% [markdown]
# Let's import some packages to deal with CSV files...

# %%
import pandas as pd

# %% [markdown]
# Let's load each file...

# %%
accidents_df = pd.read_csv(ACCIDENTS_PATH, sep=';', dtype=str)

# %%
accidents_df.head()
# Out:
#   num_acidente   chv_localidade data_acidente uf_acidente ano_acidente  \
# 0      2530504  AC1200203201801    2018-01-12          AC         2018
# 1       225803  AC1200401201801    2018-01-15          AC         2018
# 2      3109167  AC1200401201801    2018-01-16          AC         2018
# 3      1558644  AC1200401201801    2018-01-19          AC         2018
# 4      3034620  AC1200401201801    2018-01-18          AC         2018
#
#   mes_acidente mes_ano_acidente codigo_ibge     dia_semana fase_dia  ...  \
# 0           01           012018     1200203    SEXTA-FEIRA    TARDE  ...
# 1           01           012018     1200401  SEGUNDA-FEIRA    MANHA  ...
# 2           01           012018     1200401    TERCA-FEIRA    TARDE  ...
# 3           01           012018     1200401    SEXTA-FEIRA    NOITE  ...
# 4           01           012018     1200401   QUINTA-FEIRA    NOITE  ...
#
#   lim_velocidade       tp_pista  ind_guardrail ind_cantcentral  \
# ...

# %%
veiculos_df = pd.read_csv(VEHICLES_PATH, sep=';', dtype=str)

# %%
veiculos_df.head()
# Out:
#   num_acidente   tipo_veiculo ind_veic_estrangeiro qtde_veiculos
# 0          113  NAO INFORMADO        NAO INFORMADO             1
# 1          177  NAO INFORMADO        NAO INFORMADO             2
# 2          280  NAO INFORMADO        NAO INFORMADO             1
# 3          302  NAO INFORMADO        NAO INFORMADO             2
# 4          430  NAO INFORMADO        NAO INFORMADO             1

# %%
victims_df = pd.read_csv(VICTIMS_PATH, sep=';', dtype=str)

# %%
victims_df.head()
# Out:
#   num_acidente   chv_localidade data_acidente uf_acidente ano_acidente  \
# 0      3479731  AC1200401201801    2018-01-15          AC         2018
# 1      1455930  AC1200401201801    2018-01-09          AC         2018
# 2      3034619  AC1200401201801    2018-01-04          AC         2018
# 3      3109166  AC1200401201801    2018-01-14          AC         2018
# 4      1611752  AC1200401201801    2018-01-29          AC         2018
#
#   mes_acidente mes_ano_acidente         faixa_idade     genero tp_envolvido  \
# 0           01           012018  ENTRE 40 E 44 ANOS   FEMININO    MOTORISTA
# 1           01           012018  ENTRE 18 E 24 ANOS  MASCULINO    MOTORISTA
# 2           01           012018  ENTRE 25 E 29 ANOS  MASCULINO    MOTORISTA
# 3           01           012018  ENTRE 18 E 24 ANOS  MASCULINO    MOTORISTA
# 4           01           012018  ENTRE 25 E 29 ANOS  MASCULINO    MOTORISTA
#
#   gravidade_lesao equip_seguranca ind_motorista    susp_alcool  \
# ...
